# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup        #extract the data you need

# %%
import requests                     #fetch the data from web servers

# %%
url="https://www.flipkart.com/laptops/pr?sid=6bo,b5g&otracker=categorytree&fm=neo%2Fmerchandising&iid=M_fc219fa9-9236-432f-8a9e-c6021a4454cb_1_372UD5BXDFYS_MC.34WHNYFH5V2Y&otracker=hp_rich_navigation_8_1.navigationCard.RICH_NAVIGATION_Electronics~Laptop%2Band%2BDesktop_34WHNYFH5V2Y&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_8_L1_view-all&cid=34WHNYFH5V2Y"

# %%
url
# Out:
# 'https://www.flipkart.com/laptops/pr?sid=6bo,b5g&otracker=categorytree&fm=neo%2Fmerchandising&iid=M_fc219fa9-9236-432f-8a9e-c6021a4454cb_1_372UD5BXDFYS_MC.34WHNYFH5V2Y&otracker=hp_rich_navigation_8_1.navigationCard.RICH_NAVIGATION_Electronics~Laptop%2Band%2BDesktop_34WHNYFH5V2Y&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_8_L1_view-all&cid=34WHNYFH5V2Y'

# %%
Website_Allow=requests.get(url)   #used to access the contents in the page

# %%
Website_Allow
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(Website_Allow.text) #Creating a BeautifulSoup object to parse the HTML content

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
lap=soup.select("._4rR01T")    #selects specific elements from the parsed HTML content using a tag class

# %%
lap
# Out:
# [<div class="_4rR01T">Primebook Wifi MT8183 - (4 GB/64 GB EMMC Storage/Prime OS) PB Wifi Thin and Light Laptop</div>,
#  <div class="_4rR01T">HP Celeron Dual Core N4500 - (4 GB/128 GB EMMC Storage/Chrome OS) 15a- na0008TU Chromebook</div>,
#  <div class="_4rR01T">HP 2023 Athlon Dual Core 3050U - (8 GB/512 GB SSD/Windows 11 Home) 15s-ey1509AU Thin and Light Laptop</div>,
#  <div class="_4rR01T">HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/Windows 11 Home) 15s- eq2144au Thin and Light Laptop</div>,
#  <div class="_4rR01T">Lenovo Lenovo V15 Celeron Dual Core 4th Gen - (8 GB/256 GB SSD/Windows 11 Home) 82QYA00MIN Laptop</div>,
#  <div class="_4rR01T">Infinix INBook Y1 Plus Intel Core i3 10th Gen 1005G1 - (8 GB/512 GB SSD/Windows 11 Home) XL28 Thin and...</div>,
#  <div class="_4rR01T">APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/Mac OS Monterey) MLY33HN/A</div>,
# ...

# %%
lap_list=[]

# %%
#df=lap_list.columns

# %%
import time

# %%
for i in lap:
    lap_name=i.text      #gives us the text content inside that tag element
    lap_list.append(i.text)
    print(lap_list)
    time.sleep(2)
# Out:
# ['Primebook Wifi MT8183 - (4 GB/64 GB EMMC Storage/Prime OS) PB Wifi Thin and Light Laptop']
# ['Primebook Wifi MT8183 - (4 GB/64 GB EMMC Storage/Prime OS) PB Wifi Thin and Light Laptop', 'HP Celeron Dual Core N4500 - (4 GB/128 GB EMMC Storage/Chrome OS) 15a- na0008TU Chromebook']
# ['Primebook Wifi MT8183 - (4 GB/64 GB EMMC Storage/Prime OS) PB Wifi Thin and Light Laptop', 'HP Celeron Dual Core N4500 - (4 GB/128 GB EMMC Storage/Chrome OS) 15a- na0008TU Chromebook', 'HP 2023 Athlon Dual Core 3050U - (8 GB/512 GB SSD/Windows 11 Home) 15s-ey1509AU Thin and Light Laptop']
# ['Primebook Wifi MT8183 - (4 GB/64 GB EMMC Storage/Prime OS) PB Wifi Thin and Light Laptop', 'HP Celeron Dual Core N4500 - (4 GB/128 GB EMMC Storage/Chrome OS) 15a- na0008TU Chromebook', 'HP 2023 Athlon Dual Core 3050U - (8 GB/512 GB SSD/Windows 11 Home) 15s-ey1509AU Thin and Light Laptop', 'HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/Windows 11 Home) 15s- eq2144au Thin and Light Laptop']
# ...

# %%
lap_list
# Out:
# ['Primebook Wifi MT8183 - (4 GB/64 GB EMMC Storage/Prime OS) PB Wifi Thin and Light Laptop',
#  'HP Celeron Dual Core N4500 - (4 GB/128 GB EMMC Storage/Chrome OS) 15a- na0008TU Chromebook',
#  'HP 2023 Athlon Dual Core 3050U - (8 GB/512 GB SSD/Windows 11 Home) 15s-ey1509AU Thin and Light Laptop',
#  'HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/Windows 11 Home) 15s- eq2144au Thin and Light Laptop',
#  'Lenovo Lenovo V15 Celeron Dual Core 4th Gen - (8 GB/256 GB SSD/Windows 11 Home) 82QYA00MIN Laptop',
#  'Infinix INBook Y1 Plus Intel Core i3 10th Gen 1005G1 - (8 GB/512 GB SSD/Windows 11 Home) XL28 Thin and...',
#  'APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/Mac OS Monterey) MLY33HN/A',
#  'Wings Nuvobook S1 Aluminium Alloy Metal Body Intel Core i3 11th Gen 1125G4 - (8 GB/256 GB SSD/Windows ...',
#  'APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/Mac OS Monterey) MLXY3HN/A',
# ...

# %%
rating=soup.select("._1lRcqv ._3LWZlK")

# %%
rating
# Out:
# [<div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">3.9<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.7<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.7<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">3.5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
# ...

# %%
rate=[]

# %%
for j in rating:
    rate.append(j.text)

# %%
rate
# Out:
# ['4.1',
#  '3.9',
#  '4.1',
#  '4.3',
#  '4',
#  '4.2',
#  '4.7',
#  '4.2',
#  '4.7',
#  '4.2',
#  '3.5',
#  '4.4',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.2',
#  '4',
#  '3.7',
#  '4.3',
#  '4.3',
#  '3.9',
#  '4.2',
#  '4.3',
#  '4.1']

# %%
price=soup.select("._1_WHN1")

# %%
price
# Out:
# [<div class="_30jeq3 _1_WHN1">₹10,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹16,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹28,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹38,950</div>,
#  <div class="_30jeq3 _1_WHN1">₹19,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹25,617</div>,
#  <div class="_30jeq3 _1_WHN1">₹86,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹24,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹85,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹22,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹10,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹99,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹41,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹30,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹38,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹28,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹18,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹17,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹35,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹32,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹18,990</div>,
# ...

# %%
prices=[]

# %%
for k in price:
    prices.append(k.text)

# %%
prices
# Out:
# ['₹10,990',
#  '₹16,990',
#  '₹28,990',
#  '₹38,950',
#  '₹19,990',
#  '₹25,617',
#  '₹86,990',
#  '₹24,990',
#  '₹85,990',
#  '₹22,990',
#  '₹10,990',
#  '₹99,990',
#  '₹41,990',
#  '₹30,999',
#  '₹38,990',
#  '₹28,990',
#  '₹18,990',
#  '₹17,990',
#  '₹35,990',
#  '₹32,990',
#  '₹18,990',
#  '₹10,990',
#  '₹37,990',
#  '₹20,990']

# %%
rev=soup.select("._13vcmD+ span")

# %%
rev
# Out:
# [<span> 224 Reviews</span>,
#  <span> 305 Reviews</span>,
#  <span> 230 Reviews</span>,
#  <span> 472 Reviews</span>,
#  <span> 92 Reviews</span>,
#  <span> 400 Reviews</span>,
#  <span> 271 Reviews</span>,
#  <span> 41 Reviews</span>,
#  <span> 271 Reviews</span>,
#  <span> 400 Reviews</span>,
#  <span> 46 Reviews</span>,
#  <span> 22 Reviews</span>,
#  <span> 184 Reviews</span>,
#  <span> 348 Reviews</span>,
#  <span> 489 Reviews</span>,
#  <span> 289 Reviews</span>,
#  <span> 51 Reviews</span>,
#  <span> 749 Reviews</span>,
#  <span> 835 Reviews</span>,
#  <span> 849 Reviews</span>,
#  <span> 66 Reviews</span>,
#  <span> 122 Reviews</span>,
#  <span> 144 Reviews</span>,
#  <span> 99 Reviews</span>]

# %%
reviews=[]

# %%
for l in rev:
    reviews.append(l.text)

# %%
reviews
# Out:
# ['\xa0224 Reviews',
#  '\xa0305 Reviews',
#  '\xa0230 Reviews',
#  '\xa0472 Reviews',
#  '\xa092 Reviews',
#  '\xa0400 Reviews',
#  '\xa0271 Reviews',
#  '\xa041 Reviews',
#  '\xa0271 Reviews',
#  '\xa0400 Reviews',
#  '\xa046 Reviews',
#  '\xa022 Reviews',
#  '\xa0184 Reviews',
#  '\xa0348 Reviews',
#  '\xa0489 Reviews',
#  '\xa0289 Reviews',
#  '\xa051 Reviews',
#  '\xa0749 Reviews',
#  '\xa0835 Reviews',
#  '\xa0849 Reviews',
#  '\xa066 Reviews',
#  '\xa0122 Reviews',
#  '\xa0144 Reviews',
#  '\xa099 Reviews']

# %%
import pandas as pd

# %%
dataset=pd.DataFrame(lap,columns=['Prod_name'])

# %%
dataset
# Out:
#                                             Prod_name
# 0   Primebook Wifi MT8183 - (4 GB/64 GB EMMC Stora...
# 1   HP Celeron Dual Core N4500 - (4 GB/128 GB EMMC...
# 2   HP 2023 Athlon Dual Core 3050U - (8 GB/512 GB ...
# 3   HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/...
# 4   Lenovo Lenovo V15 Celeron Dual Core 4th Gen - ...
# 5   Infinix INBook Y1 Plus Intel Core i3 10th Gen ...
# 6   APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...
# 7   Wings Nuvobook S1 Aluminium Alloy Metal Body I...
# 8   APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...
# 9   Infinix INBook Y1 Plus Intel Core i3 10th Gen ...
# 10  ASUS Chromebook Celeron Dual Core N4020 - (4 G...
# 11  Acer Predator Neo (2023) Core i5 13th Gen 1350...
# 12  HP Ryzen 5 Hexa Core 5500U - (16 GB/512 GB SSD...
# 13  HP Laptop Ryzen 3 Quad Core 5300U - (8 GB/512 ...
# 14  ASUS Vivobook 15 Core i5 11th Gen 1135G7 - (8 ...
# 15  HP 2023 Ryzen 3 Dual Core 3250U - (8 GB/512 GB...
# ...

# %%
dataset['Price']= prices

# %%
dataset
# Out:
#                                             Prod_name    Price
# 0   Primebook Wifi MT8183 - (4 GB/64 GB EMMC Stora...  ₹10,990
# 1   HP Celeron Dual Core N4500 - (4 GB/128 GB EMMC...  ₹16,990
# 2   HP 2023 Athlon Dual Core 3050U - (8 GB/512 GB ...  ₹28,990
# 3   HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/...  ₹38,950
# 4   Lenovo Lenovo V15 Celeron Dual Core 4th Gen - ...  ₹19,990
# 5   Infinix INBook Y1 Plus Intel Core i3 10th Gen ...  ₹25,617
# 6   APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  ₹86,990
# 7   Wings Nuvobook S1 Aluminium Alloy Metal Body I...  ₹24,990
# 8   APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  ₹85,990
# 9   Infinix INBook Y1 Plus Intel Core i3 10th Gen ...  ₹22,990
# 10  ASUS Chromebook Celeron Dual Core N4020 - (4 G...  ₹10,990
# 11  Acer Predator Neo (2023) Core i5 13th Gen 1350...  ₹99,990
# 12  HP Ryzen 5 Hexa Core 5500U - (16 GB/512 GB SSD...  ₹41,990
# 13  HP Laptop Ryzen 3 Quad Core 5300U - (8 GB/512 ...  ₹30,999
# ...

# %%
dataset['Prod_Rate']=rate

# %%
dataset
# Out:
#                                             Prod_name    Price Prod_Rate
# 0   Primebook Wifi MT8183 - (4 GB/64 GB EMMC Stora...  ₹10,990       4.1
# 1   HP Celeron Dual Core N4500 - (4 GB/128 GB EMMC...  ₹16,990       3.9
# 2   HP 2023 Athlon Dual Core 3050U - (8 GB/512 GB ...  ₹28,990       4.1
# 3   HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/...  ₹38,950       4.3
# 4   Lenovo Lenovo V15 Celeron Dual Core 4th Gen - ...  ₹19,990         4
# 5   Infinix INBook Y1 Plus Intel Core i3 10th Gen ...  ₹25,617       4.2
# 6   APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  ₹86,990       4.7
# 7   Wings Nuvobook S1 Aluminium Alloy Metal Body I...  ₹24,990       4.2
# 8   APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  ₹85,990       4.7
# 9   Infinix INBook Y1 Plus Intel Core i3 10th Gen ...  ₹22,990       4.2
# 10  ASUS Chromebook Celeron Dual Core N4020 - (4 G...  ₹10,990       3.5
# 11  Acer Predator Neo (2023) Core i5 13th Gen 1350...  ₹99,990       4.4
# ...

# %%
dataset['Reviews']=reviews

# %%
dataset
# Out:
#                                             Prod_name    Price Prod_Rate  \
# 0   Primebook Wifi MT8183 - (4 GB/64 GB EMMC Stora...  ₹10,990       4.1
# 1   HP Celeron Dual Core N4500 - (4 GB/128 GB EMMC...  ₹16,990       3.9
# 2   HP 2023 Athlon Dual Core 3050U - (8 GB/512 GB ...  ₹28,990       4.1
# 3   HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/...  ₹38,950       4.3
# 4   Lenovo Lenovo V15 Celeron Dual Core 4th Gen - ...  ₹19,990         4
# 5   Infinix INBook Y1 Plus Intel Core i3 10th Gen ...  ₹25,617       4.2
# 6   APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  ₹86,990       4.7
# 7   Wings Nuvobook S1 Aluminium Alloy Metal Body I...  ₹24,990       4.2
# 8   APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  ₹85,990       4.7
# 9   Infinix INBook Y1 Plus Intel Core i3 10th Gen ...  ₹22,990       4.2
# 10  ASUS Chromebook Celeron Dual Core N4020 - (4 G...  ₹10,990       3.5
# 11  Acer Predator Neo (2023) Core i5 13th Gen 1350...  ₹99,990       4.4
# ...

# %% [markdown]
# ### SAVING DATASET INTO CSV FILE

# %%
import pandas as pd

# %%
dataset.to_csv("Flipkart_WebScraping.csv")

# %%
dataset1=dataset

# %%
if '__name__'=='__main__':
    dataset1=pd.read_csv("Flipkart_WebScraping.csv")
    print(dataset1)
    print(type( dataset1))
  
dataset1[' Reviews']= dataset1['Reviews'].str.replace(r'\W',"")    # removes any non-word character, and it's replaced with an empty string ""  
print(dataset1)
# Out:
#                                             Prod_name    Price Prod_Rate  \
# 0   Primebook Wifi MT8183 - (4 GB/64 GB EMMC Stora...  ₹10,990       4.1
# 1   HP Celeron Dual Core N4500 - (4 GB/128 GB EMMC...  ₹16,990       3.9
# 2   HP 2023 Athlon Dual Core 3050U - (8 GB/512 GB ...  ₹28,990       4.1
# 3   HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/...  ₹38,950       4.3
# 4   Lenovo Lenovo V15 Celeron Dual Core 4th Gen - ...  ₹19,990         4
# 5   Infinix INBook Y1 Plus Intel Core i3 10th Gen ...  ₹25,617       4.2
# 6   APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  ₹86,990       4.7
# 7   Wings Nuvobook S1 Aluminium Alloy Metal Body I...  ₹24,990       4.2
# 8   APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  ₹85,990       4.7
# 9   Infinix INBook Y1 Plus Intel Core i3 10th Gen ...  ₹22,990       4.2
# 10  ASUS Chromebook Celeron Dual Core N4020 - (4 G...  ₹10,990       3.5
# 11  Acer Predator Neo (2023) Core i5 13th Gen 1350...  ₹99,990       4.4
# ...

# %%
dataset1[' Prod_name']= dataset1['Prod_name'].str.replace(r'\W',"")      
print(dataset1)
# Out:
#                                             Prod_name    Price Prod_Rate  \
# 0   Primebook Wifi MT8183 - (4 GB/64 GB EMMC Stora...  ₹10,990       4.1
# 1   HP Celeron Dual Core N4500 - (4 GB/128 GB EMMC...  ₹16,990       3.9
# 2   HP 2023 Athlon Dual Core 3050U - (8 GB/512 GB ...  ₹28,990       4.1
# 3   HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/...  ₹38,950       4.3
# 4   Lenovo Lenovo V15 Celeron Dual Core 4th Gen - ...  ₹19,990         4
# 5   Infinix INBook Y1 Plus Intel Core i3 10th Gen ...  ₹25,617       4.2
# 6   APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  ₹86,990       4.7
# 7   Wings Nuvobook S1 Aluminium Alloy Metal Body I...  ₹24,990       4.2
# 8   APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  ₹85,990       4.7
# 9   Infinix INBook Y1 Plus Intel Core i3 10th Gen ...  ₹22,990       4.2
# 10  ASUS Chromebook Celeron Dual Core N4020 - (4 G...  ₹10,990       3.5
# 11  Acer Predator Neo (2023) Core i5 13th Gen 1350...  ₹99,990       4.4
# ...

# %%
dataset1['Price']= dataset1['Price'].str.replace(r'\W',"")      
print(dataset1)
# Out:
#                                             Prod_name  Price Prod_Rate  \
# 0   Primebook Wifi MT8183 - (4 GB/64 GB EMMC Stora...  10990       4.1
# 1   HP Celeron Dual Core N4500 - (4 GB/128 GB EMMC...  16990       3.9
# 2   HP 2023 Athlon Dual Core 3050U - (8 GB/512 GB ...  28990       4.1
# 3   HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/...  38950       4.3
# 4   Lenovo Lenovo V15 Celeron Dual Core 4th Gen - ...  19990         4
# 5   Infinix INBook Y1 Plus Intel Core i3 10th Gen ...  25617       4.2
# 6   APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  86990       4.7
# 7   Wings Nuvobook S1 Aluminium Alloy Metal Body I...  24990       4.2
# 8   APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  85990       4.7
# 9   Infinix INBook Y1 Plus Intel Core i3 10th Gen ...  22990       4.2
# 10  ASUS Chromebook Celeron Dual Core N4020 - (4 G...  10990       3.5
# 11  Acer Predator Neo (2023) Core i5 13th Gen 1350...  99990       4.4
# ...

# %%
dataset1['Prod_Rate']= dataset1['Prod_Rate'].str.replace(r'\W',"")      
print(dataset1)
# Out:
#                                             Prod_name  Price Prod_Rate  \
# 0   Primebook Wifi MT8183 - (4 GB/64 GB EMMC Stora...  10990        41
# 1   HP Celeron Dual Core N4500 - (4 GB/128 GB EMMC...  16990        39
# 2   HP 2023 Athlon Dual Core 3050U - (8 GB/512 GB ...  28990        41
# 3   HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/...  38950        43
# 4   Lenovo Lenovo V15 Celeron Dual Core 4th Gen - ...  19990         4
# 5   Infinix INBook Y1 Plus Intel Core i3 10th Gen ...  25617        42
# 6   APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  86990        47
# 7   Wings Nuvobook S1 Aluminium Alloy Metal Body I...  24990        42
# 8   APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  85990        47
# 9   Infinix INBook Y1 Plus Intel Core i3 10th Gen ...  22990        42
# 10  ASUS Chromebook Celeron Dual Core N4020 - (4 G...  10990        35
# 11  Acer Predator Neo (2023) Core i5 13th Gen 1350...  99990        44
# ...

# %%
dataset1['Prod_name']=dataset1['Prod_name'].str.replace("Windows1... ","")
print(dataset1)
# Out:
#                                             Prod_name  Price Prod_Rate  \
# 0   Primebook Wifi MT8183 - (4 GB/64 GB EMMC Stora...  10990        41
# 1   HP Celeron Dual Core N4500 - (4 GB/128 GB EMMC...  16990        39
# 2   HP 2023 Athlon Dual Core 3050U - (8 GB/512 GB ...  28990        41
# 3   HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/...  38950        43
# 4   Lenovo Lenovo V15 Celeron Dual Core 4th Gen - ...  19990         4
# 5   Infinix INBook Y1 Plus Intel Core i3 10th Gen ...  25617        42
# 6   APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  86990        47
# 7   Wings Nuvobook S1 Aluminium Alloy Metal Body I...  24990        42
# 8   APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  85990        47
# 9   Infinix INBook Y1 Plus Intel Core i3 10th Gen ...  22990        42
# 10  ASUS Chromebook Celeron Dual Core N4020 - (4 G...  10990        35
# 11  Acer Predator Neo (2023) Core i5 13th Gen 1350...  99990        44
# ...

# %%
dataset1['Prod_name']=dataset1['Prod_name'].str.replace("Windows1... ","")
print(dataset1)
# Out:
#                                             Prod_name  Price Prod_Rate  \
# 0   Primebook Wifi MT8183 - (4 GB/64 GB EMMC Stora...  10990        41
# 1   HP Celeron Dual Core N4500 - (4 GB/128 GB EMMC...  16990        39
# 2   HP 2023 Athlon Dual Core 3050U - (8 GB/512 GB ...  28990        41
# 3   HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/...  38950        43
# 4   Lenovo Lenovo V15 Celeron Dual Core 4th Gen - ...  19990         4
# 5   Infinix INBook Y1 Plus Intel Core i3 10th Gen ...  25617        42
# 6   APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  86990        47
# 7   Wings Nuvobook S1 Aluminium Alloy Metal Body I...  24990        42
# 8   APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  85990        47
# 9   Infinix INBook Y1 Plus Intel Core i3 10th Gen ...  22990        42
# 10  ASUS Chromebook Celeron Dual Core N4020 - (4 G...  10990        35
# 11  Acer Predator Neo (2023) Core i5 13th Gen 1350...  99990        44
# ...

# %%
dataset1['Reviews']=dataset1['Reviews'].str.replace("Reviews","")
print(dataset1)
# Out:
#                                             Prod_name  Price Prod_Rate  \
# 0   Primebook Wifi MT8183 - (4 GB/64 GB EMMC Stora...  10990        41
# 1   HP Celeron Dual Core N4500 - (4 GB/128 GB EMMC...  16990        39
# 2   HP 2023 Athlon Dual Core 3050U - (8 GB/512 GB ...  28990        41
# 3   HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/...  38950        43
# 4   Lenovo Lenovo V15 Celeron Dual Core 4th Gen - ...  19990         4
# 5   Infinix INBook Y1 Plus Intel Core i3 10th Gen ...  25617        42
# 6   APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  86990        47
# 7   Wings Nuvobook S1 Aluminium Alloy Metal Body I...  24990        42
# 8   APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  85990        47
# 9   Infinix INBook Y1 Plus Intel Core i3 10th Gen ...  22990        42
# 10  ASUS Chromebook Celeron Dual Core N4020 - (4 G...  10990        35
# 11  Acer Predator Neo (2023) Core i5 13th Gen 1350...  99990        44
# ...

# %%
dataset1['Prod_name']= dataset1['Prod_name'].str.replace("8 GB/256 GB SSD/Windows...","")      
print(dataset1)
# Out:
#                                             Prod_name  Price Prod_Rate  \
# 0   Primebook Wifi MT8183 - (4 GB/64 GB EMMC Stora...  10990        41
# 1   HP Celeron Dual Core N4500 - (4 GB/128 GB EMMC...  16990        39
# 2   HP 2023 Athlon Dual Core 3050U - (8 GB/512 GB ...  28990        41
# 3   HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/...  38950        43
# 4   Lenovo Lenovo V15 Celeron Dual Core 4th Gen - ...  19990         4
# 5   Infinix INBook Y1 Plus Intel Core i3 10th Gen ...  25617        42
# 6   APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  86990        47
# 7   Wings Nuvobook S1 Aluminium Alloy Metal Body I...  24990        42
# 8   APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  85990        47
# 9   Infinix INBook Y1 Plus Intel Core i3 10th Gen ...  22990        42
# 10  ASUS Chromebook Celeron Dual Core N4020 - (4 G...  10990        35
# 11  Acer Predator Neo (2023) Core i5 13th Gen 1350...  99990        44
# ...

# %%
dataset1['Prod_name']= dataset1['Prod_name'].str.replace(" (Home) 14s- dy2506TU Th...","")      
print(dataset1)
# Out:
#                                             Prod_name  Price Prod_Rate  \
# 0   Primebook Wifi MT8183 - (4 GB/64 GB EMMC Stora...  10990        41
# 1   HP Celeron Dual Core N4500 - (4 GB/128 GB EMMC...  16990        39
# 2   HP 2023 Athlon Dual Core 3050U - (8 GB/512 GB ...  28990        41
# 3   HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/...  38950        43
# 4   Lenovo Lenovo V15 Celeron Dual Core 4th Gen - ...  19990         4
# 5   Infinix INBook Y1 Plus Intel Core i3 10th Gen ...  25617        42
# 6   APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  86990        47
# 7   Wings Nuvobook S1 Aluminium Alloy Metal Body I...  24990        42
# 8   APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  85990        47
# 9   Infinix INBook Y1 Plus Intel Core i3 10th Gen ...  22990        42
# 10  ASUS Chromebook Celeron Dual Core N4020 - (4 G...  10990        35
# 11  Acer Predator Neo (2023) Core i5 13th Gen 1350...  99990        44
# ...

# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv("Flipkart_WebScraping.csv")

# %%
print(dataset.columns)
# Out:
# Index(['Unnamed: 0', 'Prod_name', 'Price', 'Prod_Rate', 'Reviews'], dtype='object')

# %%
dataset= pd.read_csv('Flipkart_WebScraping.csv', index_col=False)

# %%
dataset = dataset.drop('Unnamed: 0', axis=1)

# %%
dataset
# Out:
#                                             Prod_name    Price  Prod_Rate  \
# 0   Primebook Wifi MT8183 - (4 GB/64 GB EMMC Stora...  ₹10,990        4.1
# 1   HP Celeron Dual Core N4500 - (4 GB/128 GB EMMC...  ₹16,990        3.9
# 2   HP 2023 Athlon Dual Core 3050U - (8 GB/512 GB ...  ₹28,990        4.1
# 3   HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/...  ₹38,950        4.3
# 4   Lenovo Lenovo V15 Celeron Dual Core 4th Gen - ...  ₹19,990        4.0
# 5   Infinix INBook Y1 Plus Intel Core i3 10th Gen ...  ₹25,617        4.2
# 6   APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  ₹86,990        4.7
# 7   Wings Nuvobook S1 Aluminium Alloy Metal Body I...  ₹24,990        4.2
# 8   APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  ₹85,990        4.7
# 9   Infinix INBook Y1 Plus Intel Core i3 10th Gen ...  ₹22,990        4.2
# 10  ASUS Chromebook Celeron Dual Core N4020 - (4 G...  ₹10,990        3.5
# 11  Acer Predator Neo (2023) Core i5 13th Gen 1350...  ₹99,990        4.4
# ...

# %%
x=dataset.iloc[:,:-1].values #selects all rows and columns, except the last column
y=dataset.iloc[:,:-1].values

# %%
x
# Out:
# array([['Primebook Wifi MT8183 - (4 GB/64 GB EMMC Storage/Prime OS) PB Wifi Thin and Light Laptop',
#         '₹10,990', 4.1],
#        ['HP Celeron Dual Core N4500 - (4 GB/128 GB EMMC Storage/Chrome OS) 15a- na0008TU Chromebook',
#         '₹16,990', 3.9],
#        ['HP 2023 Athlon Dual Core 3050U - (8 GB/512 GB SSD/Windows 11 Home) 15s-ey1509AU Thin and Light Laptop',
#         '₹28,990', 4.1],
#        ['HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/Windows 11 Home) 15s- eq2144au Thin and Light Laptop',
#         '₹38,950', 4.3],
#        ['Lenovo Lenovo V15 Celeron Dual Core 4th Gen - (8 GB/256 GB SSD/Windows 11 Home) 82QYA00MIN Laptop',
#         '₹19,990', 4.0],
#        ['Infinix INBook Y1 Plus Intel Core i3 10th Gen 1005G1 - (8 GB/512 GB SSD/Windows 11 Home) XL28 Thin and...',
#         '₹25,617', 4.2],
#        ['APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/Mac OS Monterey) MLY33HN/A',
#         '₹86,990', 4.7],
# ...

# %%
y
# Out:
# array([['Primebook Wifi MT8183 - (4 GB/64 GB EMMC Storage/Prime OS) PB Wifi Thin and Light Laptop',
#         '₹10,990', 4.1],
#        ['HP Celeron Dual Core N4500 - (4 GB/128 GB EMMC Storage/Chrome OS) 15a- na0008TU Chromebook',
#         '₹16,990', 3.9],
#        ['HP 2023 Athlon Dual Core 3050U - (8 GB/512 GB SSD/Windows 11 Home) 15s-ey1509AU Thin and Light Laptop',
#         '₹28,990', 4.1],
#        ['HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/Windows 11 Home) 15s- eq2144au Thin and Light Laptop',
#         '₹38,950', 4.3],
#        ['Lenovo Lenovo V15 Celeron Dual Core 4th Gen - (8 GB/256 GB SSD/Windows 11 Home) 82QYA00MIN Laptop',
#         '₹19,990', 4.0],
#        ['Infinix INBook Y1 Plus Intel Core i3 10th Gen 1005G1 - (8 GB/512 GB SSD/Windows 11 Home) XL28 Thin and...',
#         '₹25,617', 4.2],
#        ['APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/Mac OS Monterey) MLY33HN/A',
#         '₹86,990', 4.7],
# ...

# %% [markdown]
# ## Finding null values

# %%
dataset.isnull().sum()
# Out:
# Prod_name    0
# Price        0
# Prod_Rate    0
# Reviews      0
# dtype: int64

# %%
import pandas as pd

# %%
dataset1=pd.read_csv("Flipkart_WebScraping.csv")

# %%
dataset1 = dataset1.drop('Unnamed: 0', axis=1)

# %%
dataset1
# Out:
#                                             Prod_name    Price  Prod_Rate  \
# 0   Primebook Wifi MT8183 - (4 GB/64 GB EMMC Stora...  ₹10,990          4
# 1   HP Celeron Dual Core N4500 - (4 GB/128 GB EMMC...  ₹16,990          2
# 2   HP 2023 Athlon Dual Core 3050U - (8 GB/512 GB ...  ₹28,990          4
# 3   HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/...  ₹38,950          6
# 4   Lenovo Lenovo V15 Celeron Dual Core 4th Gen - ...  ₹19,990          3
# 5   Infinix INBook Y1 Plus Intel Core i3 10th Gen ...  ₹25,617          5
# 6   APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  ₹86,990          8
# 7   Wings Nuvobook S1 Aluminium Alloy Metal Body I...  ₹24,990          5
# 8   APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  ₹85,990          8
# 9   Infinix INBook Y1 Plus Intel Core i3 10th Gen ...  ₹22,990          5
# 10  ASUS Chromebook Celeron Dual Core N4020 - (4 G...  ₹10,990          0
# 11  Acer Predator Neo (2023) Core i5 13th Gen 1350...  ₹99,990          7
# ...

# %%
dataset1.Prod_Rate.unique()
# Out:
# array([4, 2, 6, 3, 5, 8, 0, 7, 1], dtype=int64)

# %%
order=[4.4, 4.3, 3.8, 4.5, 4.2, 4. , 4.1]

# %%
order
# Out:
# [4.4, 4.3, 3.8, 4.5, 4.2, 4.0, 4.1]

# %%
import pandas as pd

# %%
from sklearn.preprocessing import LabelEncoder

# %%
dataset1=pd.DataFrame(dataset1)

# %%
dataset1
# Out:
#                                             Prod_name    Price  Prod_Rate  \
# 0   Primebook Wifi MT8183 - (4 GB/64 GB EMMC Stora...  ₹10,990          4
# 1   HP Celeron Dual Core N4500 - (4 GB/128 GB EMMC...  ₹16,990          2
# 2   HP 2023 Athlon Dual Core 3050U - (8 GB/512 GB ...  ₹28,990          4
# 3   HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/...  ₹38,950          6
# 4   Lenovo Lenovo V15 Celeron Dual Core 4th Gen - ...  ₹19,990          3
# 5   Infinix INBook Y1 Plus Intel Core i3 10th Gen ...  ₹25,617          5
# 6   APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  ₹86,990          8
# 7   Wings Nuvobook S1 Aluminium Alloy Metal Body I...  ₹24,990          5
# 8   APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  ₹85,990          8
# 9   Infinix INBook Y1 Plus Intel Core i3 10th Gen ...  ₹22,990          5
# 10  ASUS Chromebook Celeron Dual Core N4020 - (4 G...  ₹10,990          0
# 11  Acer Predator Neo (2023) Core i5 13th Gen 1350...  ₹99,990          7
# ...

# %%
lab_encode=LabelEncoder() #encoding categorical (non-numeric) data into numerical values

# %%
dataset1['Prod_Rate']=lab_encode.fit_transform(dataset1['Prod_Rate'])

# %%
dataset1
# Out:
#                                             Prod_name    Price  Prod_Rate  \
# 0   Primebook Wifi MT8183 - (4 GB/64 GB EMMC Stora...  ₹10,990          4
# 1   HP Celeron Dual Core N4500 - (4 GB/128 GB EMMC...  ₹16,990          2
# 2   HP 2023 Athlon Dual Core 3050U - (8 GB/512 GB ...  ₹28,990          4
# 3   HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/...  ₹38,950          6
# 4   Lenovo Lenovo V15 Celeron Dual Core 4th Gen - ...  ₹19,990          3
# 5   Infinix INBook Y1 Plus Intel Core i3 10th Gen ...  ₹25,617          5
# 6   APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  ₹86,990          8
# 7   Wings Nuvobook S1 Aluminium Alloy Metal Body I...  ₹24,990          5
# 8   APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  ₹85,990          8
# 9   Infinix INBook Y1 Plus Intel Core i3 10th Gen ...  ₹22,990          5
# 10  ASUS Chromebook Celeron Dual Core N4020 - (4 G...  ₹10,990          0
# 11  Acer Predator Neo (2023) Core i5 13th Gen 1350...  ₹99,990          7
# ...

# %%
dataset1['Reviews']=lab_encode.fit_transform(dataset1['Reviews']) #fits the encoder to the unique values in the column and transforms the original values into encoded integer values

# %%
dataset1
# Out:
#                                             Prod_name    Price  Prod_Rate  \
# 0   Primebook Wifi MT8183 - (4 GB/64 GB EMMC Stora...  ₹10,990          4
# 1   HP Celeron Dual Core N4500 - (4 GB/128 GB EMMC...  ₹16,990          2
# 2   HP 2023 Athlon Dual Core 3050U - (8 GB/512 GB ...  ₹28,990          4
# 3   HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/...  ₹38,950          6
# 4   Lenovo Lenovo V15 Celeron Dual Core 4th Gen - ...  ₹19,990          3
# 5   Infinix INBook Y1 Plus Intel Core i3 10th Gen ...  ₹25,617          5
# 6   APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  ₹86,990          8
# 7   Wings Nuvobook S1 Aluminium Alloy Metal Body I...  ₹24,990          5
# 8   APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  ₹85,990          8
# 9   Infinix INBook Y1 Plus Intel Core i3 10th Gen ...  ₹22,990          5
# 10  ASUS Chromebook Celeron Dual Core N4020 - (4 G...  ₹10,990          0
# 11  Acer Predator Neo (2023) Core i5 13th Gen 1350...  ₹99,990          7
# ...

# %% [markdown]
# ## Scaling

# %%
dataset1.plot.kde() #Kernel Density Estimation (KDE) plot, to estimate the probability density function of a continuous random variable
# Out:
# <AxesSubplot:ylabel='Density'>
